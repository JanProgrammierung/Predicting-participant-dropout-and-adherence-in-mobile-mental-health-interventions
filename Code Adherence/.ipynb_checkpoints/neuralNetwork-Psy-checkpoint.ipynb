# %%
import pandas as pd    #import several important packages which give us some useful features
import numpy as np
from sklearn import preprocessing
from numpy import array
import matplotlib
import matplotlib.pyplot as plt
import tensorflow as tf

#import the library classes for the neural network model
from keras.models import Sequential
from keras.layers import Dense
from tensorflow.keras import optimizers
from sklearn.datasets import make_circles
from matplotlib import pyplot

#import class for KNN missing value algorithm
from sklearn.impute import KNNImputer

#import class for MICE missing value algorithm
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer

#import class for categorical missing value algorithm
from sklearn.impute import SimpleImputer


#MICE from https://towardsdatascience.com/3-underrated-strategies-to-deal-with-missing-values-a539fb6c0690
#SimpleImputer from https://machinelearningknowledge.ai/how-to-use-sklearn-simple-imputer-simpleimputer-for-filling-missing-values-in-dataset/ and https://dzone.com/articles/imputing-missing-data-using-sklearn-simpleimputer

# %%
dataFrame = pd.read_excel('DatasetAdherence_fromIntroAndBaseline.xlsx') #loading data
dataFrame
# Out:
#      gender   age  occupation  manager  work  tenure  current  frontline  \
# 0       1.0  54.0         6.0      1.0   1.0     NaN      4.0        3.0
# 1       1.0  35.0         5.0      2.0   1.0     3.0      2.0        1.0
# 2       1.0  29.0         2.0      2.0   7.0     2.0      1.0        4.0
# 3       NaN   NaN         NaN      NaN   NaN     NaN      NaN        1.0
# 4       1.0  45.0         6.0      1.0   1.0     2.0      3.0        2.0
# ..      ...   ...         ...      ...   ...     ...      ...        ...
# 278     1.0  57.0         1.0      2.0   1.0     4.0      4.0        3.0
# 279     1.0  41.0         5.0      2.0   1.0     4.0      5.0        1.0
# 280     1.0  34.0         3.0      2.0   1.0     2.0      4.0        2.0
# 281     1.0  28.0         3.0      2.0   7.0     2.0      1.0        2.0
# 282     1.0  63.0         5.0      2.0   1.0     4.0      5.0        2.0
#
#      change  change_other  ...      olbi  phq      ptsd  req  pssRecoded  \
# 0       1.0           1.0  ...  2.285714  1.0  1.000000  4.9         2.7
# 1       1.0           2.0  ...  1.857143  1.0  1.000000  7.0         1.5
# 2       1.0           2.0  ...  2.000000  1.5  2.666667  6.4         1.5
# 3       2.0           2.0  ...  1.857143  1.5  1.000000  5.8         1.6
# 4       1.0           2.0  ...  2.428571  2.5  2.000000  2.9         2.4
# ..      ...           ...  ...       ...  ...       ...  ...         ...
# 278     2.0           2.0  ...  1.285714  2.5  1.333333  5.8         1.4
# 279     2.0           1.0  ...  1.571429  1.0  1.000000  5.2         1.5
# 280     1.0           1.0  ...  2.285714  1.0  1.666667  5.1         2.3
# 281     2.0           1.0  ...  3.285714  3.0  2.666667  5.0         3.5
# 282     2.0           1.0  ...       NaN  NaN       NaN  NaN         NaN
#
#      recovery  SocialSupport   Control      smbq  AdherenceDrop
# 0    4.666667            4.2  4.428571  2.833333              1
# 1    7.000000            4.8  6.142857  2.833333              1
# 2    6.000000            5.6  6.571429  2.000000              1
# 3    5.500000            4.2  5.285714  2.666667              1
# 4    2.500000            3.6  4.285714  4.000000              1
# ..        ...            ...       ...       ...            ...
# 278  5.333333            4.4  5.142857  1.333333              1
# 279  5.000000            4.0  5.285714  1.833333              1
# 280  4.833333            5.2  5.285714  3.500000              1
# 281  4.333333            3.2  4.714286  5.166667              1
# 282       NaN            5.0       NaN       NaN              1
#
# [283 rows x 27 columns]

# %%
dataFramePsy = dataFrame[['age', 'current', 'gad', 'jcq', 'smbq', 'req', 'maas', 'pssRecoded', 'phq', 'olbi', 'ptsd', 'AdherenceDrop']]

# %%
dataFramePsy.isnull().sum() #compute sum of missing values per column
# Out:
# age               4
# current           7
# gad              14
# jcq               9
# smbq             13
# req              13
# maas             15
# pssRecoded       16
# phq              14
# olbi             11
# ptsd             15
# AdherenceDrop     0
# dtype: int64

# %%
simpleImputer = SimpleImputer (strategy='most_frequent')
dataFramePsy.current = simpleImputer.fit_transform(dataFramePsy['current'].values.reshape(-1,1))[:,0]
# Out:
# /Users/janlorenz/opt/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py:5168: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value

# %%
dataFramePsy
# Out:
#       age  current       gad       jcq      smbq  req  maas  pssRecoded  phq  \
# 0    54.0      4.0  1.142857  4.111111  2.833333  4.9   3.0         2.7  1.0
# 1    35.0      2.0  1.000000  5.111111  2.833333  7.0   2.0         1.5  1.0
# 2    29.0      1.0  2.285714  5.888889  2.000000  6.4   2.4         1.5  1.5
# 3     NaN      5.0  1.142857  4.111111  2.666667  5.8   3.0         1.6  1.5
# 4    45.0      3.0  1.857143  4.222222  4.000000  2.9   3.2         2.4  2.5
# ..    ...      ...       ...       ...       ...  ...   ...         ...  ...
# 278  57.0      4.0  1.142857  4.333333  1.333333  5.8   1.4         1.4  2.5
# 279  41.0      5.0  1.142857  4.444444  1.833333  5.2   1.4         1.5  1.0
# 280  34.0      4.0  1.571429  5.000000  3.500000  5.1   4.0         2.3  1.0
# 281  28.0      1.0  2.142857  3.333333  5.166667  5.0   5.2         3.5  3.0
# 282  63.0      5.0       NaN  4.888889       NaN  NaN   2.0         NaN  NaN
#
#          olbi      ptsd  AdherenceDrop
# 0    2.285714  1.000000              1
# 1    1.857143  1.000000              1
# 2    2.000000  2.666667              1
# 3    1.857143  1.000000              1
# 4    2.428571  2.000000              1
# ..        ...       ...            ...
# 278  1.285714  1.333333              1
# 279  1.571429  1.000000              1
# 280  2.285714  1.666667              1
# 281  3.285714  2.666667              1
# 282       NaN       NaN              1
#
# [283 rows x 12 columns]

# %%
dataFramePsy.isnull().sum() #compute sum of missing values per column
# Out:
# age            4
# current        0
# gad           14
# jcq            9
# smbq          13
# req           13
# maas          15
# pssRecoded    16
# phq           14
# olbi          11
# ptsd          15
# FilledExit     0
# dtype: int64

# %%
imputerMICE = IterativeImputer(imputation_order='ascending',max_iter=10,random_state=42,n_nearest_features=None)
imputed_dataFramePsy = imputerMICE.fit_transform(dataFramePsy)
# Out:
# /Users/janlorenz/opt/anaconda3/lib/python3.8/site-packages/sklearn/impute/_iterative.py:669: ConvergenceWarning: [IterativeImputer] Early stopping criterion not reached.
#   warnings.warn("[IterativeImputer] Early stopping criterion not"

# %%
imputed_dataFramePsy = pd.DataFrame(imputed_dataFramePsy)
imputed_dataFramePsy.columns = ['age', 'current', 'gad', 'jcq', 'smbq', 'req', 'maas', 'pssRecoded', 'phq', 'olbi', 'ptsd', 'AdherenceDrop']
imputed_dataFramePsy
# Out:
#            age  current       gad       jcq      smbq       req  maas  \
# 0    54.000000      4.0  1.142857  4.111111  2.833333  4.900000   3.0
# 1    35.000000      2.0  1.000000  5.111111  2.833333  7.000000   2.0
# 2    29.000000      1.0  2.285714  5.888889  2.000000  6.400000   2.4
# 3    52.814126      5.0  1.142857  4.111111  2.666667  5.800000   3.0
# 4    45.000000      3.0  1.857143  4.222222  4.000000  2.900000   3.2
# ..         ...      ...       ...       ...       ...       ...   ...
# 278  57.000000      4.0  1.142857  4.333333  1.333333  5.800000   1.4
# 279  41.000000      5.0  1.142857  4.444444  1.833333  5.200000   1.4
# 280  34.000000      4.0  1.571429  5.000000  3.500000  5.100000   4.0
# 281  28.000000      1.0  2.142857  3.333333  5.166667  5.000000   5.2
# 282  63.000000      5.0  1.215491  4.888889  2.469339  5.242401   2.0
#
#      pssRecoded       phq      olbi      ptsd  AdherenceDrop
# 0      2.700000  1.000000  2.285714  1.000000            1.0
# 1      1.500000  1.000000  1.857143  1.000000            1.0
# 2      1.500000  1.500000  2.000000  2.666667            1.0
# 3      1.600000  1.500000  1.857143  1.000000            1.0
# 4      2.400000  2.500000  2.428571  2.000000            1.0
# ..          ...       ...       ...       ...            ...
# 278    1.400000  2.500000  1.285714  1.333333            1.0
# 279    1.500000  1.000000  1.571429  1.000000            1.0
# 280    2.300000  1.000000  2.285714  1.666667            1.0
# 281    3.500000  3.000000  3.285714  2.666667            1.0
# 282    1.968699  1.261118  1.880013  1.519190            1.0
#
# [283 rows x 12 columns]

# %%
#imputer = KNNImputer(n_neighbors=5)
#imputer.fit(dataFrame)
#imputed_dataFrame = imputer.transform(dataFrame)
#imputed_dataFrame = pd.DataFrame(imputed_dataFrame)
#imputed_dataFrame.columns = ["gender", "age", "occupation", "manager", "work", "tenure", "current", "frontline", "change", "change_other", "general_health", "demand_physical", "demand_private", "prev", "gad", "jcq", "maas", "olbi", "phq", "ptsd", "req", "pssRecoded", "recovery", "SocialSupport", "Control", "smbq", "FilledExit"]
#imputed_dataFrame

# %%
imputed_dataFramePsy.isnull().sum() #compute sum of missing values per column
# Out:
# age              0
# current          0
# gad              0
# jcq              0
# smbq             0
# req              0
# maas             0
# pssRecoded       0
# phq              0
# olbi             0
# ptsd             0
# AdherenceDrop    0
# dtype: int64

# %%
#feature selection

X = imputed_dataFramePsy.iloc[:,0:11]  #independent columns
y = imputed_dataFramePsy.iloc[:,-1]    #target column
from sklearn.ensemble import ExtraTreesClassifier
featureModel = ExtraTreesClassifier()
featureModel.fit(X,y)
print(featureModel.feature_importances_) #use inbuilt class feature_importances of tree based classifiers
#plot graph of feature importances for better visualization
feat_importances = pd.Series(featureModel.feature_importances_, index=X.columns)
feat_importances.nlargest(11).plot(kind='barh')
pyplot.show()
# Out:
# [0.09186099 0.11290495 0.08771183 0.1054738  0.08638069 0.09346903
#  0.09631348 0.08474648 0.06819116 0.08384985 0.08909775]

# %%
#Normalisation
x = imputed_dataFramePsy.values

# %%
print (x)
# Out:
# [[54.          4.          1.14285714 ...  2.28571429  1.
#    1.        ]
#  [35.          2.          1.         ...  1.85714286  1.
#    1.        ]
#  [29.          1.          2.28571429 ...  2.          2.66666667
#    1.        ]
#  ...
#  [34.          4.          1.57142857 ...  2.28571429  1.66666667
#    1.        ]
#  [28.          1.          2.14285714 ...  3.28571429  2.66666667
#    1.        ]
#  [63.          5.          1.21549118 ...  1.88001261  1.51919039
#    1.        ]]

# %%
min_max_scaler = preprocessing.MinMaxScaler()
x_scaled = min_max_scaler.fit_transform(x)
imputed_dataFramePsy_norm = pd.DataFrame(x_scaled, columns=imputed_dataFramePsy.columns)

# %%
imputed_dataFramePsy_norm
# Out:
#           age  current       gad       jcq      smbq       req      maas  \
# 0    0.491803     0.75  0.047619  0.431818  0.305556  0.603774  0.357143
# 1    0.180328     0.25  0.000000  0.636364  0.305556  1.000000  0.178571
# 2    0.081967     0.00  0.428571  0.795455  0.166667  0.886792  0.250000
# 3    0.472363     1.00  0.047619  0.431818  0.277778  0.773585  0.357143
# 4    0.344262     0.50  0.285714  0.454545  0.500000  0.226415  0.392857
# ..        ...      ...       ...       ...       ...       ...       ...
# 278  0.540984     0.75  0.047619  0.477273  0.055556  0.773585  0.071429
# 279  0.278689     1.00  0.047619  0.500000  0.138889  0.660377  0.071429
# 280  0.163934     0.75  0.190476  0.613636  0.416667  0.641509  0.535714
# 281  0.065574     0.00  0.380952  0.272727  0.694444  0.622642  0.750000
# 282  0.639344     1.00  0.071830  0.590909  0.244890  0.668377  0.178571
#
#      pssRecoded       phq      olbi      ptsd  AdherenceDrop
# 0      0.472222  0.000000  0.428571  0.000000            1.0
# 1      0.138889  0.000000  0.285714  0.000000            1.0
# 2      0.138889  0.166667  0.333333  0.454545            1.0
# 3      0.166667  0.166667  0.285714  0.000000            1.0
# 4      0.388889  0.500000  0.476190  0.272727            1.0
# ..          ...       ...       ...       ...            ...
# 278    0.111111  0.500000  0.095238  0.090909            1.0
# 279    0.138889  0.000000  0.190476  0.000000            1.0
# 280    0.361111  0.000000  0.428571  0.181818            1.0
# 281    0.694444  0.666667  0.761905  0.454545            1.0
# 282    0.269083  0.087039  0.293338  0.141597            1.0
#
# [283 rows x 12 columns]

# %%
#SVM & Decision Tree & Random Forest

# %%
X = imputed_dataFramePsy_norm.drop('AdherenceDrop', axis=1)
y = imputed_dataFramePsy_norm['AdherenceDrop']
X
# Out:
#           age  current       gad       jcq      smbq       req      maas  \
# 0    0.491803     0.75  0.047619  0.431818  0.305556  0.603774  0.357143
# 1    0.180328     0.25  0.000000  0.636364  0.305556  1.000000  0.178571
# 2    0.081967     0.00  0.428571  0.795455  0.166667  0.886792  0.250000
# 3    0.472363     1.00  0.047619  0.431818  0.277778  0.773585  0.357143
# 4    0.344262     0.50  0.285714  0.454545  0.500000  0.226415  0.392857
# ..        ...      ...       ...       ...       ...       ...       ...
# 278  0.540984     0.75  0.047619  0.477273  0.055556  0.773585  0.071429
# 279  0.278689     1.00  0.047619  0.500000  0.138889  0.660377  0.071429
# 280  0.163934     0.75  0.190476  0.613636  0.416667  0.641509  0.535714
# 281  0.065574     0.00  0.380952  0.272727  0.694444  0.622642  0.750000
# 282  0.639344     1.00  0.071830  0.590909  0.244890  0.668377  0.178571
#
#      pssRecoded       phq      olbi      ptsd
# 0      0.472222  0.000000  0.428571  0.000000
# 1      0.138889  0.000000  0.285714  0.000000
# 2      0.138889  0.166667  0.333333  0.454545
# 3      0.166667  0.166667  0.285714  0.000000
# 4      0.388889  0.500000  0.476190  0.272727
# ..          ...       ...       ...       ...
# 278    0.111111  0.500000  0.095238  0.090909
# 279    0.138889  0.000000  0.190476  0.000000
# 280    0.361111  0.000000  0.428571  0.181818
# 281    0.694444  0.666667  0.761905  0.454545
# 282    0.269083  0.087039  0.293338  0.141597
#
# [283 rows x 11 columns]

# %%
from sklearn.model_selection import train_test_split
from sklearn import tree
from sklearn.ensemble import RandomForestClassifier
from sklearn import metrics
from sklearn.metrics import confusion_matrix
import seaborn as sns; sns.set()
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.50, random_state=8)
clf = tree.DecisionTreeClassifier(random_state=42, criterion='entropy')
clf = clf.fit(X_train, y_train)
tree.plot_tree(clf.fit(X_train, y_train)) 
ypred = clf.predict(X_test)
print(metrics.classification_report(y_test, ypred))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.69      0.71      0.70        92
#          1.0       0.44      0.42      0.43        50
#
#     accuracy                           0.61       142
#    macro avg       0.56      0.56      0.56       142
# weighted avg       0.60      0.61      0.60       142

# %%
mat = confusion_matrix(ypred, y_test)
sns.heatmap(mat.T, annot=True, fmt='d', cbar=False)
plt.xlabel('true label')
plt.ylabel('predicted label');
b, t = plt.ylim() # discover the values for bottom and top
b += 0.5 # Add 0.5 to the bottom
t -= 0.5 # Subtract 0.5 from the top
plt.ylim(b, t) # update the ylim(bottom, top) values
plt.show()

# %%
forest = RandomForestClassifier(n_estimators=200, max_depth=25, criterion='entropy', random_state=42)
forest.fit(X_train, y_train)
ypredbag = forest.predict(X_test)
print(metrics.classification_report(y_test, ypredbag))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.67      0.77      0.72        92
#          1.0       0.42      0.30      0.35        50
#
#     accuracy                           0.61       142
#    macro avg       0.54      0.54      0.53       142
# weighted avg       0.58      0.61      0.59       142

# %%
from sklearn.metrics import confusion_matrix
mat = confusion_matrix(y_test, ypredbag)
sns.heatmap(mat.T, annot=True, fmt='d', cbar=False)
plt.xlabel('true label')
plt.ylabel('predicted label');
b, t = plt.ylim() # discover the values for bottom and top
b += 0.5 # Add 0.5 to the bottom
t -= 0.5 # Subtract 0.5 from the top
plt.ylim(b, t) # update the ylim(bottom, top) values
plt.show()

# %%
from sklearn.svm import SVC
#svm = SVC(kernel='linear')
#svm = SVC(kernel='poly', gamma='auto')
svm = SVC(kernel='rbf', gamma='auto')

svm.fit(X_train, y_train)
ypredsvm = svm.predict(X_test)
print(metrics.classification_report(y_test, ypredsvm))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.65      1.00      0.79        92
#          1.0       0.00      0.00      0.00        50
#
#     accuracy                           0.65       142
#    macro avg       0.32      0.50      0.39       142
# weighted avg       0.42      0.65      0.51       142
# /Users/janlorenz/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
from sklearn.metrics import confusion_matrix
mat = confusion_matrix(y_test, ypredsvm)
sns.heatmap(mat.T, annot=True, fmt='d', cbar=False)
plt.xlabel('true label')
plt.ylabel('predicted label');
b, t = plt.ylim() # discover the values for bottom and top
b += 0.5 # Add 0.5 to the bottom
t -= 0.5 # Subtract 0.5 from the top
plt.ylim(b, t) # update the ylim(bottom, top) values
plt.show()

# %%
#Here starts the neural network computation

# split into input (X) and output (y) variables

imputed_dataFramePsy_norm.to_csv('imputed_dataFramePsy_norm.csv', header=False)

# %%
imputed_array_norm = np.loadtxt('imputed_dataFramePsy_norm.csv', delimiter=',')

# %%
# generate 2d classification dataset
X, y = make_circles(n_samples=1000, noise=0.1, random_state=1)
# split into train and test
n_train = 500
trainX, testX = X[:n_train, :], X[n_train:, :]
trainy, testy = y[:n_train], y[n_train:]

# %%
# define the keras model

model = Sequential()

model.add(Dense(50, input_dim=2, activation='relu', kernel_initializer='he_uniform'))
model.add(Dense(1, activation='sigmoid'))
opt = tf.keras.optimizers.SGD(learning_rate=0.01, momentum=0.9)

# %%
# compile the keras model

model.compile(loss='binary_crossentropy', optimizer=opt, metrics=['accuracy'])

# %%
# fit model
history = model.fit(trainX, trainy, validation_data=(testX, testy), epochs=200, verbose=0)
# evaluate the model
_, train_acc = model.evaluate(trainX, trainy, verbose=0)
_, test_acc = model.evaluate(testX, testy, verbose=0)
print('Train: %.3f, Test: %.3f' % (train_acc, test_acc))
# plot loss during training
pyplot.subplot(211)
pyplot.title('Loss')
pyplot.plot(history.history['loss'], label='train')
pyplot.plot(history.history['val_loss'], label='test')
pyplot.legend()
# plot accuracy during training
pyplot.subplot(212)
pyplot.title('Accuracy')
pyplot.plot(history.history['accuracy'], label='train')
pyplot.plot(history.history['val_accuracy'], label='test')
pyplot.legend()
pyplot.show()
# Out:
# Train: 0.838, Test: 0.846

# %%
# evaluate the keras mode

_, mse = model.evaluate(X, y)
print('MSE: %.2f' % (mse*100))
# Out:
# 8/8 [==============================] - 0s 1ms/step - loss: 0.0891 - mse: 0.1436
# MSE: 14.36

# %% [markdown]
# #### 69.97
