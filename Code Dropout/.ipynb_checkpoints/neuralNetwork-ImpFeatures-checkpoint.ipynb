# %%
import pandas as pd    #import several important packages which give us some useful features
import numpy as np
from sklearn import preprocessing
from numpy import array
import matplotlib
import matplotlib.pyplot as plt
import tensorflow as tf

#import the library classes for the neural network model
from keras.models import Sequential
from keras.layers import Dense
from tensorflow.keras import optimizers
from sklearn.datasets import make_circles
from matplotlib import pyplot

#import class for KNN missing value algorithm
from sklearn.impute import KNNImputer

#import class for MICE missing value algorithm
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer

#import class for categorical missing value algorithm
from sklearn.impute import SimpleImputer


#MICE from https://towardsdatascience.com/3-underrated-strategies-to-deal-with-missing-values-a539fb6c0690
#SimpleImputer from https://machinelearningknowledge.ai/how-to-use-sklearn-simple-imputer-simpleimputer-for-filling-missing-values-in-dataset/ and https://dzone.com/articles/imputing-missing-data-using-sklearn-simpleimputer

# %%
dataFrame = pd.read_excel('DatasetDropout_fromIntroAndBaseline.xlsx') #loading data
dataFrame
# Out:
#      gender   age  occupation  manager  work  tenure  current  frontline  \
# 0       1.0  54.0         6.0      1.0   1.0     NaN      4.0        3.0
# 1       1.0  35.0         5.0      2.0   1.0     3.0      2.0        1.0
# 2       1.0  29.0         2.0      2.0   7.0     2.0      1.0        4.0
# 3       NaN   NaN         NaN      NaN   NaN     NaN      NaN        1.0
# 4       1.0  45.0         6.0      1.0   1.0     2.0      3.0        2.0
# ..      ...   ...         ...      ...   ...     ...      ...        ...
# 278     1.0  57.0         1.0      2.0   1.0     4.0      4.0        3.0
# 279     1.0  41.0         5.0      2.0   1.0     4.0      5.0        1.0
# 280     1.0  34.0         3.0      2.0   1.0     2.0      4.0        2.0
# 281     1.0  28.0         3.0      2.0   7.0     2.0      1.0        2.0
# 282     1.0  63.0         5.0      2.0   1.0     4.0      5.0        2.0
#
#      change  change_other  ...      olbi  phq      ptsd  req  pssRecoded  \
# 0       1.0           1.0  ...  2.285714  1.0  1.000000  4.9         2.7
# 1       1.0           2.0  ...  1.857143  1.0  1.000000  7.0         1.5
# 2       1.0           2.0  ...  2.000000  1.5  2.666667  6.4         1.5
# 3       2.0           2.0  ...  1.857143  1.5  1.000000  5.8         1.6
# 4       1.0           2.0  ...  2.428571  2.5  2.000000  2.9         2.4
# ..      ...           ...  ...       ...  ...       ...  ...         ...
# 278     2.0           2.0  ...  1.285714  2.5  1.333333  5.8         1.4
# 279     2.0           1.0  ...  1.571429  1.0  1.000000  5.2         1.5
# 280     1.0           1.0  ...  2.285714  1.0  1.666667  5.1         2.3
# 281     2.0           1.0  ...  3.285714  3.0  2.666667  5.0         3.5
# 282     2.0           1.0  ...       NaN  NaN       NaN  NaN         NaN
#
#      recovery  SocialSupport   Control      smbq  FilledExit
# 0    4.666667            4.2  4.428571  2.833333          no
# 1    7.000000            4.8  6.142857  2.833333          no
# 2    6.000000            5.6  6.571429  2.000000          no
# 3    5.500000            4.2  5.285714  2.666667          no
# 4    2.500000            3.6  4.285714  4.000000          no
# ..        ...            ...       ...       ...         ...
# 278  5.333333            4.4  5.142857  1.333333          no
# 279  5.000000            4.0  5.285714  1.833333         yes
# 280  4.833333            5.2  5.285714  3.500000          no
# 281  4.333333            3.2  4.714286  5.166667          no
# 282       NaN            5.0       NaN       NaN          no
#
# [283 rows x 27 columns]

# %%
dataFrame['FilledExit'] = ['0' if x=='no' else '1' for x in dataFrame['FilledExit']]
dataFrame
# Out:
#      gender   age  occupation  manager  work  tenure  current  frontline  \
# 0       1.0  54.0         6.0      1.0   1.0     NaN      4.0        3.0
# 1       1.0  35.0         5.0      2.0   1.0     3.0      2.0        1.0
# 2       1.0  29.0         2.0      2.0   7.0     2.0      1.0        4.0
# 3       NaN   NaN         NaN      NaN   NaN     NaN      NaN        1.0
# 4       1.0  45.0         6.0      1.0   1.0     2.0      3.0        2.0
# ..      ...   ...         ...      ...   ...     ...      ...        ...
# 278     1.0  57.0         1.0      2.0   1.0     4.0      4.0        3.0
# 279     1.0  41.0         5.0      2.0   1.0     4.0      5.0        1.0
# 280     1.0  34.0         3.0      2.0   1.0     2.0      4.0        2.0
# 281     1.0  28.0         3.0      2.0   7.0     2.0      1.0        2.0
# 282     1.0  63.0         5.0      2.0   1.0     4.0      5.0        2.0
#
#      change  change_other  ...      olbi  phq      ptsd  req  pssRecoded  \
# 0       1.0           1.0  ...  2.285714  1.0  1.000000  4.9         2.7
# 1       1.0           2.0  ...  1.857143  1.0  1.000000  7.0         1.5
# 2       1.0           2.0  ...  2.000000  1.5  2.666667  6.4         1.5
# 3       2.0           2.0  ...  1.857143  1.5  1.000000  5.8         1.6
# 4       1.0           2.0  ...  2.428571  2.5  2.000000  2.9         2.4
# ..      ...           ...  ...       ...  ...       ...  ...         ...
# 278     2.0           2.0  ...  1.285714  2.5  1.333333  5.8         1.4
# 279     2.0           1.0  ...  1.571429  1.0  1.000000  5.2         1.5
# 280     1.0           1.0  ...  2.285714  1.0  1.666667  5.1         2.3
# 281     2.0           1.0  ...  3.285714  3.0  2.666667  5.0         3.5
# 282     2.0           1.0  ...       NaN  NaN       NaN  NaN         NaN
#
#      recovery  SocialSupport   Control      smbq  FilledExit
# 0    4.666667            4.2  4.428571  2.833333           0
# 1    7.000000            4.8  6.142857  2.833333           0
# 2    6.000000            5.6  6.571429  2.000000           0
# 3    5.500000            4.2  5.285714  2.666667           0
# 4    2.500000            3.6  4.285714  4.000000           0
# ..        ...            ...       ...       ...         ...
# 278  5.333333            4.4  5.142857  1.333333           0
# 279  5.000000            4.0  5.285714  1.833333           1
# 280  4.833333            5.2  5.285714  3.500000           0
# 281  4.333333            3.2  4.714286  5.166667           0
# 282       NaN            5.0       NaN       NaN           0
#
# [283 rows x 27 columns]

# %%
dataFrameImp = dataFrame[['age', 'current', 'frontline', 'recovery', 'occupation', 'gad', 'maas', 'req', 'jcq', 'smbq', 'FilledExit']]

# %%
dataFrameImp.isnull().sum() #compute sum of missing values per column
# Out:
# age            4
# current        7
# frontline      4
# recovery      13
# occupation     3
# gad           14
# maas          15
# req           13
# jcq            9
# smbq          13
# FilledExit     0
# dtype: int64

# %%
simpleImputer = SimpleImputer (strategy='most_frequent')
dataFrameImp.occupation = simpleImputer.fit_transform(dataFrameImp['occupation'].values.reshape(-1,1))[:,0]
dataFrameImp.current = simpleImputer.fit_transform(dataFrameImp['current'].values.reshape(-1,1))[:,0]
dataFrameImp.frontline = simpleImputer.fit_transform(dataFrameImp['frontline'].values.reshape(-1,1))[:,0]
dataFrameImp.recovery = simpleImputer.fit_transform(dataFrameImp['recovery'].values.reshape(-1,1))[:,0]
# Out:
# /Users/janlorenz/opt/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py:5168: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value
# /Users/janlorenz/opt/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py:5168: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value
# /Users/janlorenz/opt/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py:5168: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value
# /Users/janlorenz/opt/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py:5168: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value

# %%
dataFrameImp
# Out:
#       age  current  frontline  recovery  occupation       gad  maas  req  \
# 0    54.0      4.0        3.0  4.666667         6.0  1.142857   3.0  4.9
# 1    35.0      2.0        1.0  7.000000         5.0  1.000000   2.0  7.0
# 2    29.0      1.0        4.0  6.000000         2.0  2.285714   2.4  6.4
# 3     NaN      5.0        1.0  5.500000         2.0  1.142857   3.0  5.8
# 4    45.0      3.0        2.0  2.500000         6.0  1.857143   3.2  2.9
# ..    ...      ...        ...       ...         ...       ...   ...  ...
# 278  57.0      4.0        3.0  5.333333         1.0  1.142857   1.4  5.8
# 279  41.0      5.0        1.0  5.000000         5.0  1.142857   1.4  5.2
# 280  34.0      4.0        2.0  4.833333         3.0  1.571429   4.0  5.1
# 281  28.0      1.0        2.0  4.333333         3.0  2.142857   5.2  5.0
# 282  63.0      5.0        2.0  4.333333         5.0       NaN   2.0  NaN
#
#           jcq      smbq FilledExit
# 0    4.111111  2.833333          0
# 1    5.111111  2.833333          0
# 2    5.888889  2.000000          0
# 3    4.111111  2.666667          0
# 4    4.222222  4.000000          0
# ..        ...       ...        ...
# 278  4.333333  1.333333          0
# 279  4.444444  1.833333          1
# 280  5.000000  3.500000          0
# 281  3.333333  5.166667          0
# 282  4.888889       NaN          0
#
# [283 rows x 11 columns]

# %%
dataFrameImp.isnull().sum() #compute sum of missing values per column
# Out:
# age            4
# current        0
# frontline      0
# recovery       0
# occupation     0
# gad           14
# maas          15
# req           13
# jcq            9
# smbq          13
# FilledExit     0
# dtype: int64

# %%
imputerMICE = IterativeImputer(imputation_order='ascending',max_iter=10,random_state=42,n_nearest_features=None)
imputed_dataFrameImp = imputerMICE.fit_transform(dataFrameImp)

# %%
imputed_dataFrameImp = pd.DataFrame(imputed_dataFrameImp)
imputed_dataFrameImp.columns = ['age', 'current', 'frontline', 'recovery', 'occupation', 'gad', 'maas', 'req', 'jcq', 'smbq', 'FilledExit']
imputed_dataFrameImp
# Out:
#            age  current  frontline  recovery  occupation       gad  maas  \
# 0    54.000000      4.0        3.0  4.666667         6.0  1.142857   3.0
# 1    35.000000      2.0        1.0  7.000000         5.0  1.000000   2.0
# 2    29.000000      1.0        4.0  6.000000         2.0  2.285714   2.4
# 3    52.964667      5.0        1.0  5.500000         2.0  1.142857   3.0
# 4    45.000000      3.0        2.0  2.500000         6.0  1.857143   3.2
# ..         ...      ...        ...       ...         ...       ...   ...
# 278  57.000000      4.0        3.0  5.333333         1.0  1.142857   1.4
# 279  41.000000      5.0        1.0  5.000000         5.0  1.142857   1.4
# 280  34.000000      4.0        2.0  4.833333         3.0  1.571429   4.0
# 281  28.000000      1.0        2.0  4.333333         3.0  2.142857   5.2
# 282  63.000000      5.0        2.0  4.333333         5.0  1.290927   2.0
#
#           req       jcq      smbq  FilledExit
# 0    4.900000  4.111111  2.833333         0.0
# 1    7.000000  5.111111  2.833333         0.0
# 2    6.400000  5.888889  2.000000         0.0
# 3    5.800000  4.111111  2.666667         0.0
# 4    2.900000  4.222222  4.000000         0.0
# ..        ...       ...       ...         ...
# 278  5.800000  4.333333  1.333333         0.0
# 279  5.200000  4.444444  1.833333         1.0
# 280  5.100000  5.000000  3.500000         0.0
# 281  5.000000  3.333333  5.166667         0.0
# 282  4.724175  4.888889  2.481825         0.0
#
# [283 rows x 11 columns]

# %%
#imputer = KNNImputer(n_neighbors=5)
#imputer.fit(dataFrame)
#imputed_dataFrame = imputer.transform(dataFrame)
#imputed_dataFrame = pd.DataFrame(imputed_dataFrame)
#imputed_dataFrame.columns = ["gender", "age", "occupation", "manager", "work", "tenure", "current", "frontline", "change", "change_other", "general_health", "demand_physical", "demand_private", "prev", "gad", "jcq", "maas", "olbi", "phq", "ptsd", "req", "pssRecoded", "recovery", "SocialSupport", "Control", "smbq", "FilledExit"]
#imputed_dataFrame

# %%
imputed_dataFrameImp.isnull().sum() #compute sum of missing values per column
# Out:
# age           0
# current       0
# frontline     0
# recovery      0
# occupation    0
# gad           0
# maas          0
# req           0
# jcq           0
# smbq          0
# FilledExit    0
# dtype: int64

# %%
#feature selection

X = imputed_dataFrameImp.iloc[:,0:10]  #independent columns
y = imputed_dataFrameImp.iloc[:,-1]    #target column
from sklearn.ensemble import ExtraTreesClassifier
featureModel = ExtraTreesClassifier()
featureModel.fit(X,y)
print(featureModel.feature_importances_) #use inbuilt class feature_importances of tree based classifiers
#plot graph of feature importances for better visualization
feat_importances = pd.Series(featureModel.feature_importances_, index=X.columns)
feat_importances.nlargest(10).plot(kind='barh')
pyplot.show()


#statistical feature selection
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2
#apply SelectKBest class to extract top 10 best features
bestfeatures = SelectKBest(score_func=chi2, k=10)
fit = bestfeatures.fit(X,y)
dfscores = pd.DataFrame(fit.scores_)
dfcolumns = pd.DataFrame(X.columns)
#concat two dataframes for better visualization 
featureScores = pd.concat([dfcolumns,dfscores],axis=1)
featureScores.columns = ['Feature','Score']  #naming the dataframe columns
print(featureScores.nlargest(10,'Score'))  #print 10 best features
# Out:
# [0.10223817 0.13749987 0.08013902 0.09667635 0.07912194 0.10056472
#  0.08784226 0.10610113 0.10697901 0.10283753]
#       Feature      Score
# 0         age  26.462313
# 1     current   8.063879
# 2   frontline   5.524680
# 4  occupation   2.643687
# 5         gad   0.800923
# 6        maas   0.332917
# 7         req   0.134404
# 8         jcq   0.050607
# 3    recovery   0.009526
# 9        smbq   0.004285

# %%
#Normalisation
x = imputed_dataFrameImp.values

# %%
print (x)
# Out:
# [[54.          4.          3.         ...  4.11111111  2.83333333
#    0.        ]
#  [35.          2.          1.         ...  5.11111111  2.83333333
#    0.        ]
#  [29.          1.          4.         ...  5.88888889  2.
#    0.        ]
#  ...
#  [34.          4.          2.         ...  5.          3.5
#    0.        ]
#  [28.          1.          2.         ...  3.33333333  5.16666667
#    0.        ]
#  [63.          5.          2.         ...  4.88888889  2.48182501
#    0.        ]]

# %%
min_max_scaler = preprocessing.MinMaxScaler()
x_scaled = min_max_scaler.fit_transform(x)
imputed_dataFrameImp_norm = pd.DataFrame(x_scaled, columns=imputed_dataFrameImp.columns)

# %%
imputed_dataFrameImp_norm
# Out:
#           age  current  frontline  recovery  occupation       gad      maas  \
# 0    0.491803     0.75       0.75   0.56250         1.0  0.047619  0.357143
# 1    0.180328     0.25       0.25   1.00000         0.8  0.000000  0.178571
# 2    0.081967     0.00       1.00   0.81250         0.2  0.428571  0.250000
# 3    0.474831     1.00       0.25   0.71875         0.2  0.047619  0.357143
# 4    0.344262     0.50       0.50   0.15625         1.0  0.285714  0.392857
# ..        ...      ...        ...       ...         ...       ...       ...
# 278  0.540984     0.75       0.75   0.68750         0.0  0.047619  0.071429
# 279  0.278689     1.00       0.25   0.62500         0.8  0.047619  0.071429
# 280  0.163934     0.75       0.50   0.59375         0.4  0.190476  0.535714
# 281  0.065574     0.00       0.50   0.50000         0.4  0.380952  0.750000
# 282  0.639344     1.00       0.50   0.50000         0.8  0.096976  0.178571
#
#           req       jcq      smbq  FilledExit
# 0    0.603774  0.431818  0.305556         0.0
# 1    1.000000  0.636364  0.305556         0.0
# 2    0.886792  0.795455  0.166667         0.0
# 3    0.773585  0.431818  0.277778         0.0
# 4    0.226415  0.454545  0.500000         0.0
# ..        ...       ...       ...         ...
# 278  0.773585  0.477273  0.055556         0.0
# 279  0.660377  0.500000  0.138889         1.0
# 280  0.641509  0.613636  0.416667         0.0
# 281  0.622642  0.272727  0.694444         0.0
# 282  0.570599  0.590909  0.246971         0.0
#
# [283 rows x 11 columns]

# %%
#Here starts the neural network computation

# split into input (X) and output (y) variables

imputed_dataFrameImp_norm.to_csv('imputed_dataFrameImp_norm.csv', header=False)

# %%
imputed_arrayImp_norm = np.loadtxt('imputed_dataFrameImp_norm.csv', delimiter=',')

# %%
# generate 2d classification dataset
X, y = make_circles(n_samples=1000, noise=0.1, random_state=1)
# split into train and test
n_train = 500
trainX, testX = X[:n_train, :], X[n_train:, :]
trainy, testy = y[:n_train], y[n_train:]

# %%
# define the keras model

model = Sequential()

model.add(Dense(50, input_dim=2, activation='relu', kernel_initializer='he_uniform'))
model.add(Dense(1, activation='sigmoid'))
opt = tf.keras.optimizers.SGD(learning_rate=0.01, momentum=0.9)

# %%
# compile the keras model

model.compile(loss='binary_crossentropy', optimizer=opt, metrics=['accuracy'])

# %%
# fit model
history = model.fit(trainX, trainy, validation_data=(testX, testy), epochs=200, verbose=0)
# evaluate the model
_, train_acc = model.evaluate(trainX, trainy, verbose=0)
_, test_acc = model.evaluate(testX, testy, verbose=0)
print('Train: %.3f, Test: %.3f' % (train_acc, test_acc))
# plot loss during training
pyplot.subplot(211)
pyplot.title('Loss')
pyplot.plot(history.history['loss'], label='train')
pyplot.plot(history.history['val_loss'], label='test')
pyplot.legend()
# plot accuracy during training
pyplot.subplot(212)
pyplot.title('Accuracy')
pyplot.plot(history.history['accuracy'], label='train')
pyplot.plot(history.history['val_accuracy'], label='test')
pyplot.legend()
pyplot.show()
# Out:
# Train: 0.832, Test: 0.846

# %%
# evaluate the keras mode

_, mse = model.evaluate(X, y)
print('MSE: %.2f' % (mse*100))
# Out:
# 8/8 [==============================] - 0s 1ms/step - loss: 0.0891 - mse: 0.1436
# MSE: 14.36

# %% [markdown]
# #### 69.97
