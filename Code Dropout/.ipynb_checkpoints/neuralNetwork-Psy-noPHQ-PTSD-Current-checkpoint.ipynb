# %%
import pandas as pd    #import several important packages which give us some useful features
import numpy as np
from sklearn import preprocessing
from numpy import array
import matplotlib
import matplotlib.pyplot as plt
import tensorflow as tf

#import the library classes for the neural network model
from keras.models import Sequential
from keras.layers import Dense
from tensorflow.keras import optimizers
from sklearn.datasets import make_circles
from matplotlib import pyplot

#import class for KNN missing value algorithm
from sklearn.impute import KNNImputer

#import class for MICE missing value algorithm
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer

#import class for categorical missing value algorithm
from sklearn.impute import SimpleImputer


#MICE from https://towardsdatascience.com/3-underrated-strategies-to-deal-with-missing-values-a539fb6c0690
#SimpleImputer from https://machinelearningknowledge.ai/how-to-use-sklearn-simple-imputer-simpleimputer-for-filling-missing-values-in-dataset/ and https://dzone.com/articles/imputing-missing-data-using-sklearn-simpleimputer

# %%
dataFrame = pd.read_excel('DatasetDropout_fromIntroAndBaseline.xlsx') #loading data
dataFrame
# Out:
#      gender   age  occupation  manager  work  tenure  current  frontline  \
# 0       1.0  54.0         6.0      1.0   1.0     NaN      4.0        3.0
# 1       1.0  35.0         5.0      2.0   1.0     3.0      2.0        1.0
# 2       1.0  29.0         2.0      2.0   7.0     2.0      1.0        4.0
# 3       NaN   NaN         NaN      NaN   NaN     NaN      NaN        1.0
# 4       1.0  45.0         6.0      1.0   1.0     2.0      3.0        2.0
# ..      ...   ...         ...      ...   ...     ...      ...        ...
# 278     1.0  57.0         1.0      2.0   1.0     4.0      4.0        3.0
# 279     1.0  41.0         5.0      2.0   1.0     4.0      5.0        1.0
# 280     1.0  34.0         3.0      2.0   1.0     2.0      4.0        2.0
# 281     1.0  28.0         3.0      2.0   7.0     2.0      1.0        2.0
# 282     1.0  63.0         5.0      2.0   1.0     4.0      5.0        2.0
#
#      change  change_other  ...      olbi  phq      ptsd  req  pssRecoded  \
# 0       1.0           1.0  ...  2.285714  1.0  1.000000  4.9         2.7
# 1       1.0           2.0  ...  1.857143  1.0  1.000000  7.0         1.5
# 2       1.0           2.0  ...  2.000000  1.5  2.666667  6.4         1.5
# 3       2.0           2.0  ...  1.857143  1.5  1.000000  5.8         1.6
# 4       1.0           2.0  ...  2.428571  2.5  2.000000  2.9         2.4
# ..      ...           ...  ...       ...  ...       ...  ...         ...
# 278     2.0           2.0  ...  1.285714  2.5  1.333333  5.8         1.4
# 279     2.0           1.0  ...  1.571429  1.0  1.000000  5.2         1.5
# 280     1.0           1.0  ...  2.285714  1.0  1.666667  5.1         2.3
# 281     2.0           1.0  ...  3.285714  3.0  2.666667  5.0         3.5
# 282     2.0           1.0  ...       NaN  NaN       NaN  NaN         NaN
#
#      recovery  SocialSupport   Control      smbq  FilledExit
# 0    4.666667            4.2  4.428571  2.833333          no
# 1    7.000000            4.8  6.142857  2.833333          no
# 2    6.000000            5.6  6.571429  2.000000          no
# 3    5.500000            4.2  5.285714  2.666667          no
# 4    2.500000            3.6  4.285714  4.000000          no
# ..        ...            ...       ...       ...         ...
# 278  5.333333            4.4  5.142857  1.333333          no
# 279  5.000000            4.0  5.285714  1.833333         yes
# 280  4.833333            5.2  5.285714  3.500000          no
# 281  4.333333            3.2  4.714286  5.166667          no
# 282       NaN            5.0       NaN       NaN          no
#
# [283 rows x 27 columns]

# %%
dataFrame['FilledExit'] = ['0' if x=='no' else '1' for x in dataFrame['FilledExit']]
dataFrame
# Out:
#      gender   age  occupation  manager  work  tenure  current  frontline  \
# 0       1.0  54.0         6.0      1.0   1.0     NaN      4.0        3.0
# 1       1.0  35.0         5.0      2.0   1.0     3.0      2.0        1.0
# 2       1.0  29.0         2.0      2.0   7.0     2.0      1.0        4.0
# 3       NaN   NaN         NaN      NaN   NaN     NaN      NaN        1.0
# 4       1.0  45.0         6.0      1.0   1.0     2.0      3.0        2.0
# ..      ...   ...         ...      ...   ...     ...      ...        ...
# 278     1.0  57.0         1.0      2.0   1.0     4.0      4.0        3.0
# 279     1.0  41.0         5.0      2.0   1.0     4.0      5.0        1.0
# 280     1.0  34.0         3.0      2.0   1.0     2.0      4.0        2.0
# 281     1.0  28.0         3.0      2.0   7.0     2.0      1.0        2.0
# 282     1.0  63.0         5.0      2.0   1.0     4.0      5.0        2.0
#
#      change  change_other  ...      olbi  phq      ptsd  req  pssRecoded  \
# 0       1.0           1.0  ...  2.285714  1.0  1.000000  4.9         2.7
# 1       1.0           2.0  ...  1.857143  1.0  1.000000  7.0         1.5
# 2       1.0           2.0  ...  2.000000  1.5  2.666667  6.4         1.5
# 3       2.0           2.0  ...  1.857143  1.5  1.000000  5.8         1.6
# 4       1.0           2.0  ...  2.428571  2.5  2.000000  2.9         2.4
# ..      ...           ...  ...       ...  ...       ...  ...         ...
# 278     2.0           2.0  ...  1.285714  2.5  1.333333  5.8         1.4
# 279     2.0           1.0  ...  1.571429  1.0  1.000000  5.2         1.5
# 280     1.0           1.0  ...  2.285714  1.0  1.666667  5.1         2.3
# 281     2.0           1.0  ...  3.285714  3.0  2.666667  5.0         3.5
# 282     2.0           1.0  ...       NaN  NaN       NaN  NaN         NaN
#
#      recovery  SocialSupport   Control      smbq  FilledExit
# 0    4.666667            4.2  4.428571  2.833333           0
# 1    7.000000            4.8  6.142857  2.833333           0
# 2    6.000000            5.6  6.571429  2.000000           0
# 3    5.500000            4.2  5.285714  2.666667           0
# 4    2.500000            3.6  4.285714  4.000000           0
# ..        ...            ...       ...       ...         ...
# 278  5.333333            4.4  5.142857  1.333333           0
# 279  5.000000            4.0  5.285714  1.833333           1
# 280  4.833333            5.2  5.285714  3.500000           0
# 281  4.333333            3.2  4.714286  5.166667           0
# 282       NaN            5.0       NaN       NaN           0
#
# [283 rows x 27 columns]

# %%
dataFramePsy = dataFrame[['age', 'gad', 'jcq', 'smbq', 'req', 'maas', 'pssRecoded', 'olbi', 'FilledExit']]

# %%
dataFramePsy.isnull().sum() #compute sum of missing values per column
# Out:
# age            4
# gad           14
# jcq            9
# smbq          13
# req           13
# maas          15
# pssRecoded    16
# olbi          11
# FilledExit     0
# dtype: int64

# %%
dataFramePsy
# Out:
#       age       gad       jcq      smbq  req  maas  pssRecoded      olbi  \
# 0    54.0  1.142857  4.111111  2.833333  4.9   3.0         2.7  2.285714
# 1    35.0  1.000000  5.111111  2.833333  7.0   2.0         1.5  1.857143
# 2    29.0  2.285714  5.888889  2.000000  6.4   2.4         1.5  2.000000
# 3     NaN  1.142857  4.111111  2.666667  5.8   3.0         1.6  1.857143
# 4    45.0  1.857143  4.222222  4.000000  2.9   3.2         2.4  2.428571
# ..    ...       ...       ...       ...  ...   ...         ...       ...
# 278  57.0  1.142857  4.333333  1.333333  5.8   1.4         1.4  1.285714
# 279  41.0  1.142857  4.444444  1.833333  5.2   1.4         1.5  1.571429
# 280  34.0  1.571429  5.000000  3.500000  5.1   4.0         2.3  2.285714
# 281  28.0  2.142857  3.333333  5.166667  5.0   5.2         3.5  3.285714
# 282  63.0       NaN  4.888889       NaN  NaN   2.0         NaN       NaN
#
#     FilledExit
# 0            0
# 1            0
# 2            0
# 3            0
# 4            0
# ..         ...
# 278          0
# 279          1
# 280          0
# 281          0
# 282          0
#
# [283 rows x 9 columns]

# %%
dataFramePsy.isnull().sum() #compute sum of missing values per column
# Out:
# age            4
# gad           14
# jcq            9
# smbq          13
# req           13
# maas          15
# pssRecoded    16
# olbi          11
# FilledExit     0
# dtype: int64

# %%
imputerMICE = IterativeImputer(imputation_order='ascending',max_iter=10,random_state=42,n_nearest_features=None)
imputed_dataFramePsy = imputerMICE.fit_transform(dataFramePsy)
# Out:
# /Users/janlorenz/opt/anaconda3/lib/python3.8/site-packages/sklearn/impute/_iterative.py:669: ConvergenceWarning: [IterativeImputer] Early stopping criterion not reached.
#   warnings.warn("[IterativeImputer] Early stopping criterion not"

# %%
imputed_dataFramePsy = pd.DataFrame(imputed_dataFramePsy)
imputed_dataFramePsy.columns = ['age', 'gad', 'jcq', 'smbq', 'req', 'maas', 'pssRecoded', 'olbi', 'FilledExit']
imputed_dataFramePsy
# Out:
#            age       gad       jcq      smbq       req  maas  pssRecoded  \
# 0    54.000000  1.142857  4.111111  2.833333  4.900000   3.0      2.7000
# 1    35.000000  1.000000  5.111111  2.833333  7.000000   2.0      1.5000
# 2    29.000000  2.285714  5.888889  2.000000  6.400000   2.4      1.5000
# 3    46.817325  1.142857  4.111111  2.666667  5.800000   3.0      1.6000
# 4    45.000000  1.857143  4.222222  4.000000  2.900000   3.2      2.4000
# ..         ...       ...       ...       ...       ...   ...         ...
# 278  57.000000  1.142857  4.333333  1.333333  5.800000   1.4      1.4000
# 279  41.000000  1.142857  4.444444  1.833333  5.200000   1.4      1.5000
# 280  34.000000  1.571429  5.000000  3.500000  5.100000   4.0      2.3000
# 281  28.000000  2.142857  3.333333  5.166667  5.000000   5.2      3.5000
# 282  63.000000  1.292348  4.888889  2.528847  5.240745   2.0      1.9135
#
#          olbi  FilledExit
# 0    2.285714         0.0
# 1    1.857143         0.0
# 2    2.000000         0.0
# 3    1.857143         0.0
# 4    2.428571         0.0
# ..        ...         ...
# 278  1.285714         0.0
# 279  1.571429         1.0
# 280  2.285714         0.0
# 281  3.285714         0.0
# 282  1.840432         0.0
#
# [283 rows x 9 columns]

# %%
#imputer = KNNImputer(n_neighbors=5)
#imputer.fit(dataFrame)
#imputed_dataFrame = imputer.transform(dataFrame)
#imputed_dataFrame = pd.DataFrame(imputed_dataFrame)
#imputed_dataFrame.columns = ["gender", "age", "occupation", "manager", "work", "tenure", "current", "frontline", "change", "change_other", "general_health", "demand_physical", "demand_private", "prev", "gad", "jcq", "maas", "olbi", "phq", "ptsd", "req", "pssRecoded", "recovery", "SocialSupport", "Control", "smbq", "FilledExit"]
#imputed_dataFrame

# %%
imputed_dataFramePsy.isnull().sum() #compute sum of missing values per column
# Out:
# age           0
# gad           0
# jcq           0
# smbq          0
# req           0
# maas          0
# pssRecoded    0
# olbi          0
# FilledExit    0
# dtype: int64

# %%
#feature selection

X = imputed_dataFramePsy.iloc[:,0:8]  #independent columns
y = imputed_dataFramePsy.iloc[:,-1]    #target column
from sklearn.ensemble import ExtraTreesClassifier
featureModel = ExtraTreesClassifier()
featureModel.fit(X,y)
print(featureModel.feature_importances_) #use inbuilt class feature_importances of tree based classifiers
#plot graph of feature importances for better visualization
feat_importances = pd.Series(featureModel.feature_importances_, index=X.columns)
feat_importances.nlargest(9).plot(kind='barh')
pyplot.show()
# Out:
# [0.13117865 0.12800637 0.12809284 0.11561427 0.13540368 0.12704749
#  0.12447308 0.11018361]

# %%
#Normalisation
x = imputed_dataFramePsy.values

# %%
print (x)
# Out:
# [[54.          1.14285714  4.11111111 ...  2.7         2.28571429
#    0.        ]
#  [35.          1.          5.11111111 ...  1.5         1.85714286
#    0.        ]
#  [29.          2.28571429  5.88888889 ...  1.5         2.
#    0.        ]
#  ...
#  [34.          1.57142857  5.         ...  2.3         2.28571429
#    0.        ]
#  [28.          2.14285714  3.33333333 ...  3.5         3.28571429
#    0.        ]
#  [63.          1.29234835  4.88888889 ...  1.91350008  1.84043207
#    0.        ]]

# %%
min_max_scaler = preprocessing.MinMaxScaler()
x_scaled = min_max_scaler.fit_transform(x)
imputed_dataFramePsy_norm = pd.DataFrame(x_scaled, columns=imputed_dataFramePsy.columns)

# %%
imputed_dataFramePsy_norm
# Out:
#           age       gad       jcq      smbq       req      maas  pssRecoded  \
# 0    0.491803  0.047619  0.431818  0.305556  0.603774  0.357143    0.472222
# 1    0.180328  0.000000  0.636364  0.305556  1.000000  0.178571    0.138889
# 2    0.081967  0.428571  0.795455  0.166667  0.886792  0.250000    0.138889
# 3    0.374055  0.047619  0.431818  0.277778  0.773585  0.357143    0.166667
# 4    0.344262  0.285714  0.454545  0.500000  0.226415  0.392857    0.388889
# ..        ...       ...       ...       ...       ...       ...         ...
# 278  0.540984  0.047619  0.477273  0.055556  0.773585  0.071429    0.111111
# 279  0.278689  0.047619  0.500000  0.138889  0.660377  0.071429    0.138889
# 280  0.163934  0.190476  0.613636  0.416667  0.641509  0.535714    0.361111
# 281  0.065574  0.380952  0.272727  0.694444  0.622642  0.750000    0.694444
# 282  0.639344  0.097449  0.590909  0.254808  0.668065  0.178571    0.253750
#
#          olbi  FilledExit
# 0    0.428571         0.0
# 1    0.285714         0.0
# 2    0.333333         0.0
# 3    0.285714         0.0
# 4    0.476190         0.0
# ..        ...         ...
# 278  0.095238         0.0
# 279  0.190476         1.0
# 280  0.428571         0.0
# 281  0.761905         0.0
# 282  0.280144         0.0
#
# [283 rows x 9 columns]

# %%
#Here starts the neural network computation

# split into input (X) and output (y) variables

imputed_dataFramePsy_norm.to_csv('imputed_dataFramePsy_norm.csv', header=False)

# %%
imputed_array_norm = np.loadtxt('imputed_dataFramePsy_norm.csv', delimiter=',')

# %%
# generate 2d classification dataset
X, y = make_circles(n_samples=1000, noise=0.1, random_state=1)
# split into train and test
n_train = 500
trainX, testX = X[:n_train, :], X[n_train:, :]
trainy, testy = y[:n_train], y[n_train:]

# %%
# define the keras model

model = Sequential()

model.add(Dense(50, input_dim=2, activation='relu', kernel_initializer='he_uniform'))
model.add(Dense(1, activation='sigmoid'))
opt = tf.keras.optimizers.SGD(learning_rate=0.01, momentum=0.9)

# %%
# compile the keras model

model.compile(loss='binary_crossentropy', optimizer=opt, metrics=['accuracy'])

# %%
# fit model
history = model.fit(trainX, trainy, validation_data=(testX, testy), epochs=200, verbose=0)
# evaluate the model
_, train_acc = model.evaluate(trainX, trainy, verbose=0)
_, test_acc = model.evaluate(testX, testy, verbose=0)
print('Train: %.3f, Test: %.3f' % (train_acc, test_acc))
# plot loss during training
pyplot.subplot(211)
pyplot.title('Loss')
pyplot.plot(history.history['loss'], label='train')
pyplot.plot(history.history['val_loss'], label='test')
pyplot.legend()
# plot accuracy during training
pyplot.subplot(212)
pyplot.title('Accuracy')
pyplot.plot(history.history['accuracy'], label='train')
pyplot.plot(history.history['val_accuracy'], label='test')
pyplot.legend()
pyplot.show()
# Out:
# Train: 0.832, Test: 0.848

# %%
# evaluate the keras mode

_, mse = model.evaluate(X, y)
print('MSE: %.2f' % (mse*100))
# Out:
# 32/32 [==============================] - 0s 1ms/step - loss: 0.3674 - accuracy: 0.8400
# MSE: 84.00
